# %% [markdown]
# ### Perform various data preprocessing techniques like handling missing data and feature scaling.

# %%
import pandas as pd

# load the CSV into a DataFrame
df = pd.read_csv("Automobile - Automobile.csv")

# check the dataset
print("Shape of dataset:", df.shape)
display(df.head())
# Out:
# Shape of dataset: (398, 9)
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0        8.0         307.0       130.0
# 1          buick skylark 320  15.0        8.0         350.0       165.0
# 2         plymouth satellite  18.0        8.0         318.0       150.0
# 3              amc rebel sst  16.0        8.0         304.0       150.0
# 4                ford torino  17.0        NaN         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0  3504.0          12.0          70    usa
# 1  3693.0          11.5          70    usa
# 2  3436.0          11.0          70    usa
# 3  3433.0          12.0          70    usa
# 4  3449.0          10.5          70    usa

# %%
# Check for missing values
print("Missing values per column:\n", df.isnull().sum())

# Optionally, show rows with missing values
display(df[df.isnull().any(axis=1)])
# Out:
# Missing values per column:
#  name             0
# mpg              0
# cylinders        3
# displacement     3
# horsepower      12
# weight           2
# acceleration     3
# model_year       0
# origin           0
# dtype: int64
#                              name   mpg  cylinders  displacement  horsepower  \
# 4                     ford torino  17.0        NaN         302.0       140.0
# 6                chevrolet impala  14.0        8.0         454.0       220.0
# 8                pontiac catalina  14.0        8.0         455.0         NaN
# 12          chevrolet monte carlo  15.0        NaN         400.0       150.0
# 15                plymouth duster  22.0        6.0         198.0        95.0
# 19   volkswagen 1131 deluxe sedan  26.0        4.0          97.0         NaN
# 23                       bmw 2002  26.0        4.0         121.0       113.0
# 32                     ford pinto  25.0        4.0          98.0         NaN
# 126                 ford maverick  21.0        6.0         200.0         NaN
# 127                    amc hornet  19.0        6.0         232.0         NaN
# 131           toyota corolla 1200  32.0        4.0          71.0         NaN
# 136              ford gran torino  16.0        8.0         302.0         NaN
# 265               dodge magnum xe  17.5        8.0           NaN       140.0
# 269                    dodge omni  30.9        NaN         105.0        75.0
# 271              plymouth sapporo  23.2        4.0           NaN       105.0
# 282               ford fairmont 4  22.3        4.0           NaN        88.0
# 284                 dodge aspen 6  20.6        6.0         225.0         NaN
# 286               ford ltd landau  17.6        8.0         302.0       129.0
# 330          renault lecar deluxe  40.9        4.0          85.0         NaN
# 336            ford mustang cobra  23.6        4.0         140.0         NaN
# 354                   renault 18i  34.5        4.0         100.0         NaN
# 374                amc concord dl  23.0        4.0         151.0         NaN
#
#      weight  acceleration  model_year  origin
# 4    3449.0          10.5          70     usa
# 6       NaN           9.0          70     usa
# 8    4425.0          10.0          70     usa
# 12   3761.0           9.5          70     usa
# 15   2833.0           NaN          70     usa
# 19   1835.0          20.5          70  europe
# 23   2234.0           NaN          70  europe
# 32   2046.0          19.0          71     usa
# 126  2875.0          17.0          74     usa
# 127  2901.0          16.0          74     usa
# 131  1836.0           NaN          74   japan
# 136  4141.0          14.0          74     usa
# 265  4080.0          13.7          78     usa
# 269  2230.0          14.5          78     usa
# 271  2745.0          16.7          78     usa
# 282  2890.0          17.3          79     usa
# 284  3360.0          16.6          79     usa
# 286     NaN          13.4          79     usa
# 330  1835.0          17.3          80  europe
# 336  2905.0          14.3          80     usa
# 354  2320.0          15.8          81  europe
# 374  3035.0          20.5          82     usa

# %%
# Fill numerical missing values with column mean
num_cols = df.select_dtypes(include='number').columns
df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

# For categorical columns (if any missing), fill with mode
cat_cols = df.select_dtypes(include='object').columns
df[cat_cols] = df[cat_cols].fillna(df[cat_cols].mode().iloc[0])

# Check again for missing values
print("Missing values after filling:\n", df.isnull().sum())
# Out:
# Missing values after filling:
#  name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
# Save cleaned DataFrame to a new CSV
cleaned_file = "Automobile_Cleaned.csv"
df.to_csv(cleaned_file, index=False)
print(f"Cleaned CSV saved as {cleaned_file}")

# Optional: download the cleaned CSV to your computer
from google.colab import files
files.download(cleaned_file)
# Out:
# Cleaned CSV saved as Automobile_Cleaned.csv

# %% [markdown]
# #### step 1: Start by importing the necessary Python libraries for data preprocessing.

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# #### Step 2: Load the placement dataset into a Pandas Dataframe.

# %%
df=pd.read_csv("data.csv")
df.head(10)
# Out:
#    sl_no gender  hsc_p     hsc_s  degree_p   degree_t  etest_p specialisation  \
# 0      1      M  91.00  Commerce     58.00   Sci&Tech    55.00         Mkt&HR
# 1      2      M  78.33   Science     77.48   Sci&Tech    86.50        Mkt&Fin
# 2      3      M    NaN      Arts     64.00  Comm&Mgmt    75.00        Mkt&Fin
# 3      4      M  52.00   Science       NaN   Sci&Tech    66.00         Mkt&HR
# 4      5      M  73.60  Commerce     73.30  Comm&Mgmt    96.80        Mkt&Fin
# 5      6      M  49.80   Science     67.25   Sci&Tech    55.00        Mkt&Fin
# 6      7      F  49.20  Commerce     79.00  Comm&Mgmt    74.28        Mkt&Fin
# 7      8      M  64.00   Science     66.00   Sci&Tech    67.00        Mkt&Fin
# 8      9      M  79.00  Commerce     72.00  Comm&Mgmt    91.34        Mkt&Fin
# 9     10      M  70.00  Commerce     61.00  Comm&Mgmt    54.00        Mkt&Fin
#
#    mba_p    salary
# 0  58.80  270000.0
# 1  66.28  200000.0
# 2  57.80  250000.0
# 3  59.43       NaN
# 4  55.50  425000.0
# 5  51.58       NaN
# 6  53.29       NaN
# 7  62.14  252000.0
# 8  61.29  231000.0
# 9  52.21       NaN

# %% [markdown]
# #### Step 3:Take a quick look at the data to understand its structure and identify any missing values or anomalies.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   hsc_p           210 non-null    float64
#  3   hsc_s           215 non-null    object
#  4   degree_p        213 non-null    float64
#  5   degree_t        215 non-null    object
#  6   etest_p         211 non-null    float64
#  7   specialisation  215 non-null    object
#  8   mba_p           214 non-null    float64
#  9   salary          148 non-null    float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 16.9+ KB

# %% [markdown]
# #### The method isnull() checks each element in the DataFrame (or Series) to see if it is NaN (Not a Number) or None (missing value).
# It returns a DataFrame (or Series) of the same shape as the input, with Boolean values:
# #### True: The value is null (NaN or None).
# #### False: The value is not null.

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# hsc_p              5
# hsc_s              0
# degree_p           2
# degree_t           0
# etest_p            4
# specialisation     0
# mba_p              1
# salary            67
# dtype: int64

# %% [markdown]
# #### Step 4: Handle Missing Data
# #### Option 1: If the dataset is large and only a small percentage of data is missing, you can remove rows with missing values.

# %%
df.dropna(subset=["salary"],inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           148 non-null    int64
#  1   gender          148 non-null    object
#  2   hsc_p           146 non-null    float64
#  3   hsc_s           148 non-null    object
#  4   degree_p        147 non-null    float64
#  5   degree_t        148 non-null    object
#  6   etest_p         146 non-null    float64
#  7   specialisation  148 non-null    object
#  8   mba_p           148 non-null    float64
#  9   salary          148 non-null    float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 12.7+ KB

# %% [markdown]
# #### Option 2:If removing data isn't ideal, you can impute (fill in) missing values using methods like mean, median, or most frequent.

# %%
df["hsc_p"].fillna(df["hsc_p"].mean(),inplace=True)
df["degree_p"].fillna(df["degree_p"].mean(),inplace=True)
df["etest_p"].fillna(df["etest_p"].mean(),inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           148 non-null    int64
#  1   gender          148 non-null    object
#  2   hsc_p           148 non-null    float64
#  3   hsc_s           148 non-null    object
#  4   degree_p        148 non-null    float64
#  5   degree_t        148 non-null    object
#  6   etest_p         148 non-null    float64
#  7   specialisation  148 non-null    object
#  8   mba_p           148 non-null    float64
#  9   salary          148 non-null    float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 12.7+ KB

# %% [markdown]
# #### Step 5: Feature Scaling
#
#
# <img src="https://i.postimg.cc/G21gMYnF/f.png" alt="Image Description" width="500">
#
#
#
#
#
#
#
#
#
#  Option 1: This method scales the data to have a mean of 0 and a standard deviation of 1.

# %%
nc=["hsc_p","degree_p","etest_p","salary"]
SC1=StandardScaler()
df[nc]=SC1.fit_transform(df[nc])
df.head(6)
# Out:
#    sl_no gender         hsc_p     hsc_s  degree_p   degree_t   etest_p  \
# 0      1      M  2.265997e+00  Commerce -1.652293   Sci&Tech -1.328518
# 1      2      M  8.987875e-01   Science  1.346845   Sci&Tech  0.978332
# 2      3      M  1.533482e-15      Arts -0.728534  Comm&Mgmt  0.136149
# 4      5      M  3.883770e-01  Commerce  0.703293  Comm&Mgmt  1.732635
# 7      8      M -6.475513e-01   Science -0.420614   Sci&Tech -0.449718
# 8      9      M  9.710867e-01  Commerce  0.503145  Comm&Mgmt  1.332781
#
#   specialisation  mba_p    salary
# 0         Mkt&HR  58.80 -0.200292
# 1        Mkt&Fin  66.28 -0.951839
# 2        Mkt&Fin  57.80 -0.415019
# 4        Mkt&Fin  55.50  1.463849
# 7        Mkt&Fin  62.14 -0.393547
# 8        Mkt&Fin  61.29 -0.619011

# %% [markdown]
# #### Option 2:This method scales the data to a fixed range, usually between 0 and 1.

# %%
SC2=MinMaxScaler()
df[nc]=SC2.fit_transform(df[nc])
df.head()
# Out:
#    sl_no gender     hsc_p     hsc_s  degree_p   degree_t   etest_p  \
# 0      1      M  0.857051  Commerce  0.057143   Sci&Tech  0.104167
# 1      2      M  0.586729   Science  0.613714   Sci&Tech  0.760417
# 2      3      M  0.409023      Arts  0.228571  Comm&Mgmt  0.520833
# 4      5      M  0.485812  Commerce  0.494286  Comm&Mgmt  0.975000
# 7      8      M  0.280990   Science  0.285714   Sci&Tech  0.354167
#
#   specialisation  mba_p    salary
# 0         Mkt&HR  58.80  0.094595
# 1        Mkt&Fin  66.28  0.000000
# 2        Mkt&Fin  57.80  0.067568
# 4        Mkt&Fin  55.50  0.304054
# 7        Mkt&Fin  62.14  0.070270

# %% [markdown]
# ####  Step 6:Separate the dataset into features (X) and target (y) variables. The target is usually the column you want to predict.

# %%
X=df[["gender","hsc_p","hsc_s","degree_p","degree_t","etest_p","specialisation","mba_p"]]
Y=df["salary"]

# %% [markdown]
# ### Step 7: After preprocessing, save the cleaned and scaled dataset to a new CSV file

# %%
final=pd.concat([X,Y],axis=1)
final.to_csv("Pre.csv",index=False)

# %%
# Lab-1 Activities

#Perform data preprocesing for Automobile.csv

#i. Delete the column horsepower since it has few missing values

#ii. Impute missing with median

#iii. Apply min-max scaling and standardization on the Automobiles.csv and provide the reasoning which feature scaling method make more sense to this dataset.
